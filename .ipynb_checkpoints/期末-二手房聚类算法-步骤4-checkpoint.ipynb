# %% [markdown]
# ## 四、聚类算法

# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

import matplotlib.pyplot as plt
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['simhei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

from sklearn.cluster import KMeans
from sklearn.cluster import MeanShift, estimate_bandwidth
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-a876e2b40366> in <module>
#       8 mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
#       9
# ---> 10 from sklearn.cluster import KMeans
#      11 from sklearn.cluster import MeanShift, estimate_bandwidth
#
# D:\Anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# D:\Anaconda3\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# ...

# %%
df = pd.read_csv(r'./广州二手房数据清洗结果.csv')
df
# Out:
#        Unnamed: 0 HouseName Address  totalPrice  unitPrice region   Type  \
# 0               0    中海誉城北苑      香雪       223.0    39554.0    黄埔区  1室1厅
# 1               1    中海誉城北苑      香雪       320.0    36489.0    黄埔区  2室2厅
# 2               2    中海誉城北苑      香雪       212.0    37602.0    黄埔区  1室1厅
# 3               5    中海誉城北苑      香雪       210.0    37254.0    黄埔区  1室1厅
# 4               6    中海誉城北苑      香雪       446.0    36489.0    黄埔区  3室1厅
# ...           ...       ...     ...         ...        ...    ...    ...
# 50695       64938       华仙楼     沙太南       275.0    29954.0    越秀区  3室2厅
# 50696       64939       华仙楼     沙太南       320.0    34855.0    越秀区  3室2厅
# 50697       64941       田美居     同德围       210.0    28611.0    越秀区  2室1厅
# 50698       64942       田美居     同德围       184.0    25035.0    越秀区  2室1厅
# 50699       64943       田美居     同德围       178.0    25071.0    越秀区  2室1厅
#
#          area direction dectype  year banta floorType  buildyear
# ...

# %%
plt.figure(figsize=(10,8),dpi=256)
colors = ['red', 'red', 'red', 'red',
            'blue', 'blue', 'blue', 'blue',
            'green', 'green', 'green', 'green',
            'gray', 'gray', 'gray', 'gray']
addr_dist = ['黄浦','徐汇','长宁','虹口',
                '普陀','杨浦','静安','浦东',
                '闵行', '宝山','松江','嘉定',
                '青浦','奉贤', '金山', '崇明']
markers = ['o','s','v','x',
            'o', 's', 'v', 'x',
            'o', 's', 'v', 'x',
            'o', 's', 'v', 'x']
print(addr_dist)
for i in range(16):
    x = df.loc[df['addr_dist'] == addr_dist[i]]['area']
    y = df.loc[df['addr_dist'] == addr_dist[i]]['price']
    plt.scatter(x, y, c=colors[i], s=20, label=addr_dist[i], marker=markers[i])
 
 
plt.legend(loc=1,bbox_to_anchor=(1.138,1.0),fontsize=12)
plt.xlim(0,500)
plt.ylim(0,200000)
plt.title('上海各区二手房面积对房价的影响',fontsize=20)
plt.xlabel('房屋面积（平方米）',fontsize=16)
plt.ylabel('房屋单价（元/平方米）',fontsize=16)
plt.savefig('picture/上海各区二手房面积对房价的影响.jpg')
 
plot_scatter()
